# %% [markdown]
# # Calculate the Jensen-Shannon Divergence

# %%
import vae_tools
import vae_tools.sanity
import vae_tools.viz
import vae_tools.callbacks
vae_tools.sanity.check()
from tensorflow.keras.datasets import mnist
import tensorflow as tf
import numpy as np
import glob
import pickle
# Out:
# python version:  3.5.2
# keras version: 2.2.4-tf
# tensorflow version: 2.0.2
# matplotlib uses:  module://ipykernel.pylab.backend_inline
# No GPUs available

# %%
def js_calc(z_ab, z_a, z_b, z_logvar_ab, z_logvar_a, z_logvar_b, n_z, n_samples):
    z_ab = z_ab[:n_z]
    z_a = z_a[:n_z]
    z_b = z_b[:n_z]
    z_logvar_ab = z_logvar_ab[:n_z]
    z_logvar_a = z_logvar_a[:n_z]
    z_logvar_b = z_logvar_b[:n_z]
    js_d_ab = vae_tools.metrics.js_loss(z_ab, z_ab, z_logvar_ab, z_logvar_ab, n_samples)
    js_d_ab_a = vae_tools.metrics.js_loss(z_ab, z_a, z_logvar_ab, z_logvar_a, n_samples)
    js_d_ab_b = vae_tools.metrics.js_loss(z_ab, z_b, z_logvar_ab, z_logvar_b, n_samples)
    js_d_b_a = vae_tools.metrics.js_loss(z_a, z_b, z_logvar_a, z_logvar_b, n_samples)
    return js_d_ab, js_d_ab_a, js_d_ab_b, js_d_b_a


def run(seed = '0', loc = '/mnt/ssd_pcie/mmvae_mnist_split/'):
    dump_loc = loc + seed
    n_z = 10000 # Samples in latent space
    n_samples = 100 # Monte Carlo Samples

    # Get the MNIST digits
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train = x_train.astype('float32') / 255.
    x_test = x_test.astype('float32') / 255.
    x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
    x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

    # Cut down data set for testing
    #x_train = x_train[:10,:]
    #y_train = y_train[:10]
    #x_test = x_test[:10,:]
    #y_test = y_test[:10]

    # input image dimensions
    img_rows, img_cols, img_chns = 28, 28, 1
    original_dim = img_rows * img_cols * img_chns
    split_dim = int(original_dim / 2)

    # Split it horizontally
    x_train_a = x_train[:,:split_dim]
    x_train_b = x_train[:,split_dim:]
    x_test_a = x_test[:,:split_dim]
    x_test_b = x_test[:,split_dim:]


    for net_str_m in glob.glob(dump_loc + '/enc_mean*11.h5'):
        net_str_lv = net_str_m.replace('mean', 'logvar')

        # Load the models

        print("load models")
        # Remove the suffix (like '11.h5')
        model_enc_mean, _ = vae_tools.vae.GenericVae.load_model_powerset(net_str_m[:-5], 2)
        model_enc_logvar, _ = vae_tools.vae.GenericVae.load_model_powerset(net_str_lv[:-5], 2)


        model_enc_mean_a = model_enc_mean[0]
        model_enc_mean_b = model_enc_mean[1]
        model_enc_mean_ab = model_enc_mean[2]

        model_enc_logvar_a = model_enc_logvar[0]
        model_enc_logvar_b = model_enc_logvar[1]
        model_enc_logvar_ab = model_enc_logvar[2]

        # Predict the test data
        print("predict data")
        z_train_ab = model_enc_mean_ab.predict([x_train_a, x_train_b])
        z_train_a = model_enc_mean_a.predict(x_train_a)
        z_train_b = model_enc_mean_b.predict(x_train_b)

        z_test_ab = model_enc_mean_ab.predict([x_test_a, x_test_b])
        z_test_a = model_enc_mean_a.predict(x_test_a)
        z_test_b = model_enc_mean_b.predict(x_test_b)

        z_train_logvar_ab = model_enc_logvar_ab.predict([x_train_a, x_train_b])
        z_train_logvar_a = model_enc_logvar_a.predict(x_train_a)
        z_train_logvar_b = model_enc_logvar_b.predict(x_train_b)

        z_test_logvar_ab = model_enc_logvar_ab.predict([x_test_a, x_test_b])
        z_test_logvar_a = model_enc_logvar_a.predict(x_test_a)
        z_test_logvar_b = model_enc_logvar_b.predict(x_test_b)

        # Cleanup tghe models
        for m_m, m_lv in zip(model_enc_mean, model_enc_logvar):
            del m_m, m_lv
        tf.keras.backend.clear_session()


        # Get the JS divergence
        print("calc js")
        import time

        start = time.time()
        js_d_ab, js_d_ab_a, js_d_ab_b, js_d_b_a = js_calc(z_test_ab, z_test_a, z_test_b, z_test_logvar_ab, z_test_logvar_a, z_test_logvar_b, n_z, n_samples)
        js_d_ab_train, js_d_ab_a_train, js_d_ab_b_train, js_d_b_a_train = js_calc(z_train_ab, z_train_a, z_train_b, z_train_logvar_ab, z_train_logvar_a, z_train_logvar_b, n_z, n_samples)
        end = time.time()
        print(end - start)
        js = {'test_ab_vs_ab': js_d_ab,
              'test_ab_vs_a': js_d_ab_a,
              'test_ab_vs_b': js_d_ab_b,
              'test_b_vs_a': js_d_b_a,
              'train_ab_vs_ab': js_d_ab_train,
              'train_ab_vs_a': js_d_ab_a_train,
              'train_ab_vs_b': js_d_ab_b_train,
              'train_b_vs_a': js_d_b_a_train}

        fn = net_str_m.replace('enc_mean', 'jsd').replace('_11.h5', '.p')
        print("write " + fn)
        with open(fn, 'wb') as handle:
            pickle.dump(js, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4921205043792725
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_45_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4639711380004883
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_57_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4385802745819092
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_22_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4484925270080566
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_24_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4449970722198486
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_39_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4356253147125244
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_2_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4323666095733643
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_37_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.434971809387207
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_12_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4294440746307373
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_3_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4307177066802979
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_26_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4295756816864014
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_19_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4286868572235107
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_32_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4396131038665771
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_16_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.430525302886963
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_46_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4358665943145752
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_56_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4350266456604004
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_58_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4352054595947266
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_53_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4362733364105225
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_13_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.437910795211792
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_17_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.435157060623169
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_52_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4337258338928223
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_27_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.439208984375
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_9_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.430877923965454
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_14_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4264640808105469
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_48_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4298467636108398
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_20_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4336161613464355
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_0_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4304628372192383
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_59_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4384102821350098
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_23_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4370613098144531
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_35_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4401004314422607
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_30_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4357819557189941
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_6_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4320626258850098
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_43_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.5716536045074463
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_4_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.437713861465454
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_1_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4337036609649658
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_55_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4330480098724365
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_5_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4308781623840332
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_42_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4267754554748535
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_25_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4286892414093018
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_51_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.432488203048706
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_28_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4310836791992188
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_47_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4259800910949707
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_18_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.432133436203003
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_41_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4228384494781494
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_40_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4307847023010254
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_49_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.427863597869873
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_21_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.42840576171875
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_34_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4276907444000244
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_11_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.426367998123169
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_10_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.5733757019042969
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_50_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4327538013458252
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_29_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.431229591369629
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_36_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.434800148010254
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_8_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4285669326782227
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_31_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.431152105331421
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_38_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4279327392578125
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_54_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.436659812927246
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_7_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4300882816314697
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_44_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4263229370117188
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_33_a.p
# load models
# ffffffffffffffffffffffffffffffffaaaaaaaaaaaaaaaaaaaaaaaaaaaake
# calc js
# 1.4384570121765137
# write /mnt/ssd_pcie/mmvae_mnist_split_1/jsd_15_a.p
